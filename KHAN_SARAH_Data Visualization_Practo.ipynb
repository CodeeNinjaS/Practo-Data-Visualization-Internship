# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\sarah\Downloads\heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
df
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0                          0       1         1          1   40       1
# 1                          0       0         0          0   25       1
# 2                          0       1         1          1   28       0
# 3                          0       1         0          1   27       0
# 4                          0       1         1          1   24       0
# ...                      ...     ...       ...        ...  ...     ...
# 253675                     0       1         1          1   45       0
# 253676                     0       1         1          1   18       0
# 253677                     0       0         0          1   28       0
# 253678                     0       1         0          1   23       0
# 253679                     1       1         1          1   25       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  \
# ...

# %%
# the shape of the dataframe
df.shape
# Out:
# (253680, 22)

# %%
df.head()
# Out:
#    HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                     0       1         1          1   40       1       0
# 1                     0       0         0          0   25       1       0
# 2                     0       1         1          1   28       0       0
# 3                     0       1         0          1   27       0       0
# 4                     0       1         1          1   24       0       0
#
#    Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  NoDocbcCost  GenHlth  \
# 0         0             0       0  ...              1            0        5
# 1         0             1       0  ...              0            1        3
# 2         0             0       1  ...              1            1        5
# 3         0             1       1  ...              1            0        2
# 4         0             1       1  ...              1            0        2
#
#    MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  int64
#  1   HighBP                253680 non-null  int64
#  2   HighChol              253680 non-null  int64
#  3   CholCheck             253680 non-null  int64
#  4   BMI                   253680 non-null  int64
#  5   Smoker                253680 non-null  int64
#  6   Stroke                253680 non-null  int64
#  7   Diabetes              253680 non-null  int64
#  8   PhysActivity          253680 non-null  int64
#  9   Fruits                253680 non-null  int64
#  10  Veggies               253680 non-null  int64
#  11  HvyAlcoholConsump     253680 non-null  int64
#  12  AnyHealthcare         253680 non-null  int64
#  13  NoDocbcCost           253680 non-null  int64
# ...

# %%
# check for null values
pd.isnull(df).sum()
# Out:
# HeartDiseaseorAttack    0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# Diabetes                0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
duplicateValues = df.duplicated()
print(duplicateValues.sum())
df[duplicateValues]
# Out:
# 23899
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 1242                       0       1         1          1   27       1
# 1563                       0       0         0          1   21       1
# 2700                       0       0         0          1   32       0
# 3160                       0       0         0          1   21       0
# 3332                       0       0         0          1   24       0
# ...                      ...     ...       ...        ...  ...     ...
# 253492                     0       1         1          1   33       0
# 253550                     0       0         0          1   25       0
# 253563                     0       0         1          1   24       1
# 253597                     0       0         0          1   24       0
# 253638                     0       0         0          1   24       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  \
# ...

# %%
# drop duplicated values
df.drop_duplicates(inplace=True)

# %%
duplicatedValues = df.duplicated()
duplicatedValues.sum()
# Out:
# 0

# %%
# descriptive stats
df.describe()
# Out:
#        HeartDiseaseorAttack         HighBP       HighChol      CholCheck  \
# count         229781.000000  229781.000000  229781.000000  229781.000000
# mean               0.103216       0.454441       0.441760       0.959535
# std                0.304241       0.497921       0.496598       0.197047
# min                0.000000       0.000000       0.000000       0.000000
# 25%                0.000000       0.000000       0.000000       1.000000
# 50%                0.000000       0.000000       0.000000       1.000000
# 75%                0.000000       1.000000       1.000000       1.000000
# max                1.000000       1.000000       1.000000       1.000000
#
#                 BMI         Smoker         Stroke       Diabetes  \
# count  229781.00000  229781.000000  229781.000000  229781.000000
# mean       28.68567       0.465661       0.044756       0.325627
# std         6.78636       0.498821       0.206767       0.724623
# ...

# %%
df.boxplot(column=['BMI'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['BMI'] >= (Q1 - 1.5 * IQR)) & (df['BMI'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['BMI'])
plt.show()

# %%
df.boxplot(column=['HeartDiseaseorAttack'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['HeartDiseaseorAttack'].quantile(0.25)
Q3 = df['HeartDiseaseorAttack'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['HeartDiseaseorAttack'] >= (Q1 - 1.5 * IQR)) & (df['HeartDiseaseorAttack'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['HeartDiseaseorAttack'])
plt.show()

# %%
df.boxplot(column=['HighBP'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['HighBP'].quantile(0.25)
Q3 = df['HighBP'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['HighBP'] >= (Q1 - 1.5 * IQR)) & (df['HighBP'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['HighBP'])
plt.show()

# %%
df.boxplot(column=['HighChol'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['HighChol'].quantile(0.25)
Q3 = df['HighChol'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['HighChol'] >= (Q1 - 1.5 * IQR)) & (df['HighChol'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['HighChol'])
plt.show()

# %%
df.boxplot(column=['CholCheck'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['CholCheck'].quantile(0.25)
Q3 = df['CholCheck'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['CholCheck'] >= (Q1 - 1.5 * IQR)) & (df['CholCheck'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['CholCheck'])
plt.show()

# %%
df.boxplot(column=['Smoker'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Smoker'].quantile(0.25)
Q3 = df['Smoker'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Smoker'] >= (Q1 - 1.5 * IQR)) & (df['Smoker'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Smoker'])
plt.show()

# %%
df.boxplot(column=['Stroke'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Stroke'].quantile(0.25)
Q3 = df['Stroke'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Stroke'] >= (Q1 - 1.5 * IQR)) & (df['Stroke'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Stroke'])
plt.show()

# %%
df.boxplot(column=['Diabetes'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Diabetes'].quantile(0.25)
Q3 = df['Diabetes'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Diabetes'] >= (Q1 - 1.5 * IQR)) & (df['Diabetes'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Diabetes'])
plt.show()

# %%
df.boxplot(column=['PhysActivity'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['PhysActivity'].quantile(0.25)
Q3 = df['PhysActivity'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['PhysActivity'] >= (Q1 - 1.5 * IQR)) & (df['PhysActivity'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['PhysActivity'])
plt.show()

# %%
df.boxplot(column=['Fruits'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Fruits'].quantile(0.25)
Q3 = df['Fruits'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Fruits'] >= (Q1 - 1.5 * IQR)) & (df['Fruits'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Fruits'])
plt.show()

# %%
df.boxplot(column=['Veggies'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Veggies'].quantile(0.25)
Q3 = df['Veggies'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Veggies'] >= (Q1 - 1.5 * IQR)) & (df['Veggies'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Veggies'])
plt.show()

# %%
df.boxplot(column=['HvyAlcoholConsump'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['HvyAlcoholConsump'].quantile(0.25)
Q3 = df['HvyAlcoholConsump'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['HvyAlcoholConsump'] >= (Q1 - 1.5 * IQR)) & (df['HvyAlcoholConsump'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['HvyAlcoholConsump'])
plt.show()

# %%
df.boxplot(column=['NoDocbcCost'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['NoDocbcCost'].quantile(0.25)
Q3 = df['NoDocbcCost'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['NoDocbcCost'] >= (Q1 - 1.5 * IQR)) & (df['NoDocbcCost'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['NoDocbcCost'])
plt.show()

# %%
df.boxplot(column=['GenHlth'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['GenHlth'].quantile(0.25)
Q3 = df['GenHlth'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['GenHlth'] >= (Q1 - 1.5 * IQR)) & (df['GenHlth'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['GenHlth'])
plt.show()

# %%
df.boxplot(column=['MentHlth'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['MentHlth'].quantile(0.25)
Q3 = df['MentHlth'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['MentHlth'] >= (Q1 - 1.5 * IQR)) & (df['MentHlth'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['MentHlth'])
plt.show()

# %%
df.boxplot(column=['PhysHlth'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['PhysHlth'].quantile(0.25)
Q3 = df['PhysHlth'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['PhysHlth'] >= (Q1 - 1.5 * IQR)) & (df['PhysHlth'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['PhysHlth'])
plt.show()

# %%
df.boxplot(column=['DiffWalk'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['DiffWalk'].quantile(0.25)
Q3 = df['DiffWalk'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['DiffWalk'] >= (Q1 - 1.5 * IQR)) & (df['DiffWalk'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['DiffWalk'])
plt.show()

# %%
df.boxplot(column=['Education'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Education'].quantile(0.25)
Q3 = df['Education'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Education'] >= (Q1 - 1.5 * IQR)) & (df['Education'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Education'])
plt.show()

# %%
df.boxplot(column=['Income'])
plt.show()

# %%
# Remove outliers using IQR method
Q1 = df['Income'].quantile(0.25)
Q3 = df['Income'].quantile(0.75)
IQR = Q3 - Q1
filter = (df['Income'] >= (Q1 - 1.5 * IQR)) & (df['Income'] <= (Q3 + 1.5 * IQR))
df = df.loc[filter]

# %%
df.boxplot(column=['Income'])
plt.show()

# %%
# Bar Plots and Pie Charts

# %%
#A. Visualizing Categorical Variables: Smoking Status, Physical Activity, Fruit, and Vegetable Consumption

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\sarah\Downloads\heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
# Plot bar chart for Smoking Status
plt.figure(figsize=(8, 6))
df['Smoker'].value_counts().plot(kind='bar', color=['pink', 'blue'])
plt.title('Distribution of Smoking Status')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# %%
# Plot bar chart for PhysActivity
plt.figure(figsize=(8, 6))
df['PhysActivity'].value_counts().plot(kind='bar', color=['green', 'red'])
plt.title('Distribution of Physical Activity')
plt.xlabel('PhysActivity')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# %%
# Plot bar chart for Fruits
plt.figure(figsize=(8, 6))
df['Fruits'].value_counts().plot(kind='bar', color=['purple', 'yellow'])
plt.title('Distribution of Fruit Consumption')
plt.xlabel('Fruits')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# %%
# Plot bar chart for Veggies
plt.figure(figsize=(8, 6))
df['Veggies'].value_counts().plot(kind='bar', color=['brown', 'cyan'])
plt.title('Distribution of Vegetable Consumption')
plt.xlabel('Veggies')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.show()

# %%
#B. Comparing Heart Disease Prevalence Across Different Categorical Variables

# %%
# Grouped bar chart for HighBP vs Heart Disease
highbp_hd = df.groupby(['HighBP', 'HeartDiseaseorAttack']).size().unstack()
highbp_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['skyblue', 'orange'])
plt.title('Heart Disease by High Blood Pressure')
plt.xlabel('High Blood Pressure')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for HighChol vs Heart Disease
highchol_hd = df.groupby(['HighChol', 'HeartDiseaseorAttack']).size().unstack()
highchol_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['green', 'red'])
plt.title('Heart Disease by High Cholesterol')
plt.xlabel('High Cholesterol')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for CholCheck vs Heart Disease
cholcheck_hd = df.groupby(['CholCheck', 'HeartDiseaseorAttack']).size().unstack()
cholcheck_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['blue', 'brown'])
plt.title('Heart Disease by Cholesterol Check')
plt.xlabel('Cholesterol Check')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Smoking Status vs Heart Disease
smoker_hd = df.groupby(['Smoker', 'HeartDiseaseorAttack']).size().unstack()
smoker_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['pink','teal' ])
plt.title('Heart Disease by Smoking Status')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Stroke vs Heart Disease
stroke_hd = df.groupby(['Stroke', 'HeartDiseaseorAttack']).size().unstack()
stroke_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['purple', 'yellow'])
plt.title('Heart Disease by Stroke')
plt.xlabel('Stroke')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for PhysActivity vs Heart Disease
physactivity_hd = df.groupby(['PhysActivity', 'HeartDiseaseorAttack']).size().unstack()
physactivity_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['cyan', 'magenta'])
plt.title('Heart Disease by Physical Activity')
plt.xlabel('Physical Activity')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Fruits vs Heart Disease
fruits_hd = df.groupby(['Fruits', 'HeartDiseaseorAttack']).size().unstack()
fruits_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['purple', 'yellow'])
plt.title('Heart Disease by Fruit Consumption')
plt.xlabel('Fruits')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Veggies vs Heart Disease
veggies_hd = df.groupby(['Veggies', 'HeartDiseaseorAttack']).size().unstack()
veggies_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['brown', 'cyan'])
plt.title('Heart Disease by Vegetable Consumption')
plt.xlabel('Veggies')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for HvyAlcoholConsump vs Heart Disease
hvyalcohol_hd = df.groupby(['HvyAlcoholConsump', 'HeartDiseaseorAttack']).size().unstack()
hvyalcohol_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['lime','maroon'])
plt.title('Heart Disease by Heavy Alcohol Consumption')
plt.xlabel('Heavy Alcohol Consumption')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for AnyHealthcare vs Heart Disease
anyhealthcare_hd = df.groupby(['AnyHealthcare', 'HeartDiseaseorAttack']).size().unstack()
anyhealthcare_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['navy', 'yellow'])
plt.title('Heart Disease by Any Healthcare')
plt.xlabel('Any Healthcare')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for NoDocbcCost vs Heart Disease
nodocbccost_hd = df.groupby(['NoDocbcCost', 'HeartDiseaseorAttack']).size().unstack()
nodocbccost_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['orange', 'purple'])
plt.title('Heart Disease by No Doctor Because of Cost')
plt.xlabel('No Doctor Because of Cost')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for DiffWalk vs Heart Disease
diffwalk_hd = df.groupby(['DiffWalk', 'HeartDiseaseorAttack']).size().unstack()
diffwalk_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['green', 'pink'])
plt.title('Heart Disease by Difficulty Walking')
plt.xlabel('Difficulty Walking')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Sex vs Heart Disease
sex_hd = df.groupby(['Sex', 'HeartDiseaseorAttack']).size().unstack()
sex_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['blue', 'red'])
plt.title('Heart Disease by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'], rotation=0)
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Education vs Heart Disease
education_hd = df.groupby(['Education', 'HeartDiseaseorAttack']).size().unstack()
education_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['pink', 'cyan'])
plt.title('Heart Disease by Education')
plt.xlabel('Education')
plt.ylabel('Count')
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Grouped bar chart for Income vs Heart Disease
income_hd = df.groupby(['Income', 'HeartDiseaseorAttack']).size().unstack()
income_hd.plot(kind='bar', stacked=False, figsize=(10, 7), color=['purple', 'orange'])
plt.title('Heart Disease by Income')
plt.xlabel('Income')
plt.ylabel('Count')
plt.legend(title='Heart Disease or Attack', labels=['No', 'Yes'])
plt.show()

# %%
# Explore other Visualization Techniques

# %%
# A. Visualizing Distributions of BMI, Mental Health Days, and Physical Health Days

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\sarah\Downloads\heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
# Plot histogram for BMI

plt.figure(figsize=(10, 6))
sns.histplot(df['BMI'], bins=30, kde=True)
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram for Mental Health Days (MentHlth)
plt.figure(figsize=(10, 6))
sns.histplot(df['MentHlth'], bins=30, kde=True, color='blue', alpha=0.7)
plt.title('Distribution of Mental Health Days (MentHlth)')
plt.xlabel('Mental Health Days')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram for Physical Health Days (PhysHlth)
plt.figure(figsize=(10, 5))
plt.hist(df['PhysHlth'], bins=30, edgecolor='black')
plt.title('Distribution of Physical Health Days (PhysHlth)')
plt.xlabel('Physical Health Days')
plt.ylabel('Frequency')
plt.show()

# %%
# B. Correlation Heatmap: Visualizing Variable Relationships

# %%
import seaborn as sns
import numpy as np

# Calculate the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, linecolor='black')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# C. Exploring Heart Disease: Visualizing Key Variable Relationships with Scatter Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\sarah\Downloads\heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
# Plotting scatter plot between BMI and HeartDiseaseorAttack
plt.figure(figsize=(10, 6))
sns.scatterplot(x='BMI', y='HeartDiseaseorAttack', data=df)
plt.title('Scatter Plot of BMI vs Heart Disease')
plt.xlabel('BMI')
plt.ylabel('Heart Disease or Attack')
plt.show()

# %%
# Plotting scatter plot between HighChol and HeartDiseaseorAttack
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HighChol', y='HeartDiseaseorAttack', data=df)
plt.title('Scatter Plot of HighChol vs Heart Disease')
plt.xlabel('HighChol')
plt.ylabel('Heart Disease or Attack')
plt.show()

# %%
# Plotting scatter plot between Smoker and HeartDiseaseorAttack
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Smoker', y='HeartDiseaseorAttack', data=df)
plt.title('Scatter Plot of Smoker vs Heart Disease')
plt.xlabel('Smoker')
plt.ylabel('Heart Disease or Attack')
plt.show()

# %%
# Plotting scatter plot between HighBP and HeartDiseaseorAttack
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HighBP', y='HeartDiseaseorAttack', data=df)
plt.title('Scatter Plot of HighBP vs HeartDiseaseorAttack')
plt.xlabel('HighBP')
plt.ylabel('HeartDiseaseorAttack ')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and Diabetes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='Diabetes', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs Diabetes')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('Diabetes')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and HvyAlcoholConsump
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='HvyAlcoholConsump', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs HvyAlcoholConsump')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('HvyAlcoholConsump')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and Stroke
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='Stroke', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs Stroke')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('Stroke')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and MentHlth
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='MentHlth', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs MentHlth')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('MentHlth')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and PhysHlth
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='PhysHlth', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs PhysHlth')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('PhysHlth')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and Age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='Age', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs Age')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('Age')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and Veggies
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='Education', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs Education')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('Education')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and Income
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='Income', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs Income')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('Income')
plt.show()

# %%
# Plotting scatter plot between HeartDiseaseorAttack and GenHlth
plt.figure(figsize=(10, 6))
sns.scatterplot(x='HeartDiseaseorAttack', y='GenHlth', data=df)
plt.title('Scatter Plot of HeartDiseaseorAttack vs GenHlth')
plt.xlabel('HeartDiseaseorAttack')
plt.ylabel('GenHlth')
plt.show()

# %%
#d. Line Plots: Displaying trends across ordered categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\sarah\Downloads\heart_disease_health_indicators_BRFSS2015 2 (1).csv")

# %%
# Create age groups (binned)
df['AgeGroup'] = pd.cut(df['Age'], bins=10, labels=[f'Group {i+1}' for i in range(10)])

# Aggregate data by AgeGroup
age_group_trend = df.groupby('AgeGroup')['HeartDiseaseorAttack'].mean().reset_index()

# Create a line plot for AgeGroup vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='AgeGroup', y='HeartDiseaseorAttack', data=age_group_trend, marker='o')
plt.title('Line Plot of Heart Disease by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.xticks(rotation=45)
plt.show()

# %%
# Create income groups (binned)
df['IncomeGroup'] = pd.cut(df['Income'], bins=10, labels=[f'Group {i+1}' for i in range(10)])

# Aggregate data by IncomeGroup
income_group_trend = df.groupby('IncomeGroup')['HeartDiseaseorAttack'].mean().reset_index()

# Create a line plot for IncomeGroup vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='IncomeGroup', y='HeartDiseaseorAttack', data=income_group_trend, marker='o')
plt.title('Line Plot of Heart Disease by Income Group')
plt.xlabel('Income Group')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the order of education levels
education_order = {
    1: 'No formal education',
    2: 'Some high school',
    3: 'High school graduate',
    4: 'Some college',
    5: 'College graduate',
    6: 'Postgraduate education'
}


# Convert 'Education' to a categorical type with an ordered category
df['Education'] = pd.Categorical(df['Education'], categories=[1, 2, 3, 4, 5, 6], ordered=True)

# %%
# Aggregate data by Education
education_trend = df.groupby('Education')['HeartDiseaseorAttack'].mean().reset_index()

# %%
# Create a line plot for Education vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='Education', y='HeartDiseaseorAttack', data=education_trend, marker='o')
plt.title('Line Plot of Heart Disease by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.xticks(ticks=list(education_order.keys()), labels=list(education_order.values()), rotation=45)
plt.show()

# %%
sex_labels = {
    0: 'Female', 
    1: 'Male'
}

# Convert 'Sex' to a categorical type
df['Sex'] = pd.Categorical(df['Sex'], categories=[0, 1], ordered=False)

# Aggregate data by Sex
sex_trend = df.groupby('Sex')['HeartDiseaseorAttack'].mean().reset_index()
# Create a line plot for Sex vs. Heart Disease
plt.figure(figsize=(10, 6))
sns.lineplot(x='Sex', y='HeartDiseaseorAttack', data=sex_trend, marker='o')
plt.title('Line Plot of Heart Disease by Sex')
plt.xlabel('Sex')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])
plt.show()

# %%
# Create BMI categories
bmi_bins = [0, 18.5, 24.9, 29.9, 40]  # Define your bins (e.g., underweight, normal, overweight, obese)
bmi_labels = ['Underweight', 'Normal weight', 'Overweight', 'Obese']
df['BMICategory'] = pd.cut(df['BMI'], bins=bmi_bins, labels=bmi_labels)

# Aggregate data by BMICategory
bmi_trend = df.groupby('BMICategory')['HeartDiseaseorAttack'].mean().reset_index()

# Create a line plot for BMI categories vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='BMICategory', y='HeartDiseaseorAttack', data=bmi_trend, marker='o')
plt.title('Line Plot of Heart Disease by BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.xticks(rotation=45)
plt.show()

# %%
# Aggregate data by GenHlth
genhlth_trend = df.groupby('GenHlth')['HeartDiseaseorAttack'].mean().reset_index()

# Create a line plot for General Health vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='GenHlth', y='HeartDiseaseorAttack', data=genhlth_trend, marker='o')
plt.title('Line Plot of Heart Disease by General Health')
plt.xlabel('General Health')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.show()

# %%
# Aggregate data by PhysHlth
physhlth_trend = df.groupby('PhysHlth')['HeartDiseaseorAttack'].mean().reset_index()

# Create a line plot for Physical Health vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='PhysHlth', y='HeartDiseaseorAttack', data=physhlth_trend, marker='o')
plt.title('Line Plot of Heart Disease by Physical Health')
plt.xlabel('Physical Health')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.show()

# %%
# Aggregate data by MentHlth
menthlth_trend = df.groupby('MentHlth')['HeartDiseaseorAttack'].mean().reset_index()

# Create a line plot for Mental Health vs. Heart Disease
plt.figure(figsize=(12, 6))
sns.lineplot(x='MentHlth', y='HeartDiseaseorAttack', data=menthlth_trend, marker='o')
plt.title('Line Plot of Heart Disease by Mental Health')
plt.xlabel('Mental Health')
plt.ylabel('Heart Disease or Attack (Mean)')
plt.show()

# %%
# E. Violin Plots: Merging Box and Density Plots for Enhanced Data Distribution Insights

# %%
# Create a violin plot for HeartDiseaseorAttack by Age group

plt.figure(figsize=(12, 6))
sns.violinplot(x='Age', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Age')
plt.xlabel('Age')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for BMI by HeartDiseaseorAttack
plt.figure(figsize=(12, 6))
sns.violinplot(x='HeartDiseaseorAttack', y='BMI', data=df)
plt.title('Violin Plot of BMI Distribution by Heart Disease')
plt.xlabel('Heart Disease or Attack')
plt.ylabel('BMI')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Income
plt.figure(figsize=(12, 6))
sns.violinplot(x='Income', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Income')
plt.xlabel('Income')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Education level
plt.figure(figsize=(12, 6))
sns.violinplot(x='Education', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of Age Distribution by Education Level')
plt.xlabel('Education Level')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Sex
plt.figure(figsize=(12, 6))
sns.violinplot(x='Sex', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Sex')
plt.xlabel('Sex')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by MentHlth
plt.figure(figsize=(12, 6))
sns.violinplot(x='MentHlth', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by MentHlth')
plt.xlabel('MentHlth ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by GenHlth
plt.figure(figsize=(12, 6))
sns.violinplot(x='GenHlth', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by GenHlth')
plt.xlabel('GenHlth ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Diabetes
plt.figure(figsize=(12, 6))
sns.violinplot(x='Diabetes', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Diabetes')
plt.xlabel('Diabetes ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by HvyAlcoholConsump
plt.figure(figsize=(12, 6))
sns.violinplot(x='HvyAlcoholConsump', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by HvyAlcoholConsump')
plt.xlabel('HvyAlcoholConsump ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by HighBP
plt.figure(figsize=(12, 6))
sns.violinplot(x='HighBP', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by HighBP')
plt.xlabel('HighBP ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by HighChol
plt.figure(figsize=(12, 6))
sns.violinplot(x='HighChol', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by HighChol')
plt.xlabel('HighChol ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Smoker
plt.figure(figsize=(12, 6))
sns.violinplot(x='Smoker', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Smoker')
plt.xlabel('Smoker ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Stroke
plt.figure(figsize=(12, 6))
sns.violinplot(x='Stroke', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Stroke')
plt.xlabel('Stroke ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by PhysActivity
plt.figure(figsize=(12, 6))
sns.violinplot(x='PhysActivity', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by PhysActivity')
plt.xlabel('PhysActivity ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by NoDocbcCost
plt.figure(figsize=(12, 6))
sns.violinplot(x='NoDocbcCost', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by NoDocbcCost')
plt.xlabel('NoDocbcCost ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by DiffWalk
plt.figure(figsize=(12, 6))
sns.violinplot(x='DiffWalk', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by DiffWalk')
plt.xlabel('DiffWalk ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Fruits Consumption
plt.figure(figsize=(12, 6))
sns.violinplot(x='Fruits', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Fruits')
plt.xlabel('Fruits ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# Create a violin plot for HeartDiseaseorAttack by Vegetable Consumption
plt.figure(figsize=(12, 6))
sns.violinplot(x='Veggies', y='HeartDiseaseorAttack', data=df)
plt.title('Violin Plot of HeartDiseaseorAttack Distribution by Veggies')
plt.xlabel('Veggies ')
plt.ylabel('HeartDiseaseorAttack')
plt.show()

# %%
# F. Pair Plots: Unveiling Relationships Across Multiple Variables

# %%
#Basic Health Metrics
subset = df[['BMI', 'MentHlth', 'PhysHlth', 'Age']]

# Plot pairwise relationships
sns.pairplot(subset)
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %%
# Health Conditions
subset = df[['HeartDiseaseorAttack', 'HighBP', 'HighChol', 'Diabetes']]

# Plot pairwise relationships
sns.pairplot(subset)
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %%
# Lifestyle Factors
subset = df[['Smoker', 'PhysActivity', 'Fruits', 'Veggies']]

# Plot pairwise relationships
sns.pairplot(subset)
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %%
# Healthcare and Costs
subset = df[['AnyHealthcare', 'NoDocbcCost', 'HvyAlcoholConsump', 'GenHlth']]

# Plot pairwise relationships
sns.pairplot(subset)
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %%
# Demographics
subset = df[['Sex', 'Age', 'Education', 'Income']]

# Plot pairwise relationships
sns.pairplot(subset)
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %%
# Other Health Factors
subset = df[['DiffWalk', 'Stroke','CholCheck']]

# Plot pairwise relationships
sns.pairplot(subset)
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()
